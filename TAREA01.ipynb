# %% [markdown]
# 1.   Genera una lista que consista de $20$ números que estén en el intervalo $[-1,1]$. Llámala `Lista_1`.
# 2.   Genera una lista que consista de $20$ números que sean enteros en el intervalo $[1500, 3000]$. Llámala `Lista_2`.
# 3. Crea un diccionario cuyas llaves sean "**CapSmall**" y "**CapLarge**" y sus valores sean la `Lista_1` y `Lista_2`, respectivamente.
# 4. Crea un `DataFrame` a partir del diccionario del punto anterior. Llámalo df.
# 5. Reindexa los índices poniendo Año 1$,...,$ Año 20.
# 6. Realiza una explicación de la estadística descriptiva de tu `DataFrame`.
# 7. ¿Cuál es el valor mínimo de la columna "**CapSmall**"?
# 8. ¿Cuál es "**CapLarge**" promedio del año 10 al año 20.
# 9. Realiza una gráfica de Año contra "**CapLarge**".
# 10. Muestra el `DataFrame` que obtienes si tomas aquellos valores de "**CapLarge**" mayores a $2000$. ¿Cuál es la dimensión (shape) de tu nueva base de datos?

# %%
import numpy as np

Lista_1= np.random.uniform(-1,1,20)

# %%
Lista_1
# Out:
# array([-0.46308072, -0.9792551 , -0.79753458,  0.3234423 ,  0.26985949,
#        -0.26805943, -0.80202763, -0.56561522, -0.73847908, -0.548666  ,
#        -0.32022234, -0.50669286, -0.7158511 , -0.44777984,  0.99140688,
#         0.76009696,  0.8296572 ,  0.68405614, -0.75929526,  0.78822958])

# %%
Lista_2= np.random.randint(1500,3000,20)

# %%
Lista_2
# Out:
# array([2779, 2845, 2371, 2052, 2117, 1844, 2565, 1956, 2110, 2130, 2302,
#        2714, 1940, 2409, 2625, 1964, 2895, 1640, 2312, 1595])

# %%
import pandas as pd

diccionario={"CapSmall":Lista_1,
             "CapLarge": Lista_2}
df=pd.DataFrame(diccionario, index=["Año 1", "Año 2", "Año 3", "Año 4", "Año 5", "Año 6", "Año 7", "Año 8", "Año 9", "Año 10", "Año 11", "Año 12", "Año 13", "Año 14", "Año 15", "Año 16", "Año 17", "Año 18", "Año 19", "Año 20"])
df
# Out:
#         CapSmall  CapLarge
# Año 1  -0.463081      2779
# Año 2  -0.979255      2845
# Año 3  -0.797535      2371
# Año 4   0.323442      2052
# Año 5   0.269859      2117
# Año 6  -0.268059      1844
# Año 7  -0.802028      2565
# Año 8  -0.565615      1956
# Año 9  -0.738479      2110
# Año 10 -0.548666      2130
# Año 11 -0.320222      2302
# Año 12 -0.506693      2714
# Año 13 -0.715851      1940
# Año 14 -0.447780      2409
# Año 15  0.991407      2625
# Año 16  0.760097      1964
# Año 17  0.829657      2895
# Año 18  0.684056      1640
# Año 19 -0.759295      2312
# Año 20  0.788230      1595

# %%
df.describe()
# Out:
#         CapSmall     CapLarge
# count  20.000000    20.000000
# mean   -0.163291  2258.250000
# std     0.661815   388.745063
# min    -0.979255  1595.000000
# 25%    -0.721508  1962.000000
# 50%    -0.455430  2216.000000
# 75%     0.413596  2580.000000
# max     0.991407  2895.000000

# %%
min(Lista_1)
# Out:
# -0.979255098157441

# %%
promedio=df.iloc[9:20]
promedio= promedio.drop(columns=["CapSmall"])
promedio
# Out:
#         CapLarge
# Año 10      2130
# Año 11      2302
# Año 12      2714
# Año 13      1940
# Año 14      2409
# Año 15      2625
# Año 16      1964
# Año 17      2895
# Año 18      1640
# Año 19      2312
# Año 20      1595

# %%
promedio.mean()
# Out:
# CapLarge    2229.636364
# dtype: float64

# %%
df.drop(columns=["CapSmall"])
# Out:
#         CapLarge
# Año 1       2779
# Año 2       2845
# Año 3       2371
# Año 4       2052
# Año 5       2117
# Año 6       1844
# Año 7       2565
# Año 8       1956
# Año 9       2110
# Año 10      2130
# Año 11      2302
# Año 12      2714
# Año 13      1940
# Año 14      2409
# Año 15      2625
# Año 16      1964
# Año 17      2895
# Año 18      1640
# Año 19      2312
# Año 20      1595
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['CapLarge'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['CapLarge'], **{})
# chart

# %%
mayores= df[df["CapLarge"]>2000]
mayores= mayores.drop(columns=["CapSmall"])
mayores
# Out:
#         CapLarge
# Año 1       2779
# Año 2       2845
# Año 3       2371
# Año 4       2052
# Año 5       2117
# Año 7       2565
# Año 9       2110
# Año 10      2130
# Año 11      2302
# Año 12      2714
# Año 14      2409
# Año 15      2625
# Año 17      2895
# Año 19      2312

# %%
mayores.shape
# Out:
# (14, 1)
