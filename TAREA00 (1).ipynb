# %% [markdown]
# #TAREA TABLA 10x10

# %%
Cartera={"Airbnb": [22,37,90,87,65,43,21,87,34,27],
          "Walmart": [35,76,55,33,17,42,29,100,67,89],
          "Chedraui": [21,67,87,99,23,45,67,89,92,12],
          "Apple": [34,65,78,95,44,23,16,87,45,33],
          "Volaris": [75,88,33,46,94,22,37,48,55,91],
          "Coca Cola": [11,93,27,67,45,67,86,23,10,38],
          "Dell": [76,89,23,56,88,77,13,56,33,11],
          "Casio": [34,67,45,55,66,89,90,23,31,26],
          "Hp":[98,45,67,87,98,32,24,45,67,65],
          "Bimbo":[22,87,34,56,77,23,34,54,65,78]}

# %%
print(Cartera)
# Out:
# {'Airbnb': [22, 37, 90, 87, 65, 43, 21, 87, 34, 27], 'Walmart': [35, 76, 55, 33, 17, 42, 29, 100, 67, 89], 'Chedraui': [21, 67, 87, 99, 23, 45, 67, 89, 92, 12], 'Apple': [34, 65, 78, 95, 44, 23, 16, 87, 45, 33], 'Volaris': [75, 88, 33, 46, 94, 22, 37, 48, 55, 91], 'Coca Cola': [11, 93, 27, 67, 45, 67, 86, 23, 10, 38], 'Dell': [76, 89, 23, 56, 88, 77, 13, 56, 33, 11], 'Casio': [34, 67, 45, 55, 66, 89, 90, 23, 31, 26], 'Hp': [98, 45, 67, 87, 98, 32, 24, 45, 67, 65], 'Bimbo': [22, 87, 34, 56, 77, 23, 34, 54, 65, 78]}

# %%
import pandas as pd

# %%
Empresas= pd.DataFrame(Cartera)
Empresas
# Out:
#    Airbnb  Walmart  Chedraui  Apple  Volaris  Coca Cola  Dell  Casio  Hp  \
# 0      22       35        21     34       75         11    76     34  98
# 1      37       76        67     65       88         93    89     67  45
# 2      90       55        87     78       33         27    23     45  67
# 3      87       33        99     95       46         67    56     55  87
# 4      65       17        23     44       94         45    88     66  98
# 5      43       42        45     23       22         67    77     89  32
# 6      21       29        67     16       37         86    13     90  24
# 7      87      100        89     87       48         23    56     23  45
# 8      34       67        92     45       55         10    33     31  67
# 9      27       89        12     33       91         38    11     26  65
#
#    Bimbo
# 0     22
# 1     87
# 2     34
# 3     56
# 4     77
# 5     23
# 6     34
# 7     54
# 8     65
# 9     78
# ...

# %%
type(Empresas)
# Out:
# pandas.core.frame.DataFrame

# %%
Empresas["Apple"]
# Out:
# 0    34
# 1    65
# 2    78
# 3    95
# 4    44
# 5    23
# 6    16
# 7    87
# 8    45
# 9    33
# Name: Apple, dtype: int64

# %%
type(Empresas["Apple"])
# Out:
# pandas.core.series.Series

# %%
Empresas.iloc[1]
# Out:
# Airbnb       37
# Walmart      76
# Chedraui     67
# Apple        65
# Volaris      88
# Coca Cola    93
# Dell         89
# Casio        67
# Hp           45
# Bimbo        87
# Name: 1, dtype: int64

# %%
Empresas[["Dell","Hp"]]
# Out:
#    Dell  Hp
# 0    76  98
# 1    89  45
# 2    23  67
# 3    56  87
# 4    88  98
# 5    77  32
# 6    13  24
# 7    56  45
# 8    33  67
# 9    11  65

# %%
Empresas.iloc[0:4]
# Out:
#    Airbnb  Walmart  Chedraui  Apple  Volaris  Coca Cola  Dell  Casio  Hp  \
# 0      22       35        21     34       75         11    76     34  98
# 1      37       76        67     65       88         93    89     67  45
# 2      90       55        87     78       33         27    23     45  67
# 3      87       33        99     95       46         67    56     55  87
#
#    Bimbo
# 0     22
# 1     87
# 2     34
# 3     56
