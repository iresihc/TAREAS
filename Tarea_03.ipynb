# %% [markdown]
# #Ana Paula Maya e Iresi Hernandez

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
d = pd.read_csv("/content/drive/MyDrive/PROGRAMACION/precios_muestra.csv")
d
# Out:
#       BLUE   ORANGE
# 0   8.7000  10.6600
# 1   8.9055  11.0828
# 2   8.7113  10.7100
# 3   8.4346  11.5907
# 4   8.7254  12.1070
# 5   9.0551  11.7876
# 6   8.9514  11.2078
# 7   9.2439  12.5192
# 8   9.1276  13.3624
# 9   9.3976  14.4080
# 10  9.4554  11.9837
# 11  9.5704  12.2718
# 12  9.7728  11.5892

# %%
#rendimiento ssimple
rendimientos= d.pct_change().dropna()
rendimientos
# Out:
#         BLUE    ORANGE
# 1   0.023621  0.039662
# 2  -0.021807 -0.033638
# 3  -0.031763  0.082232
# 4   0.034477  0.044544
# 5   0.037786 -0.026381
# 6  -0.011452 -0.049187
# 7   0.032676  0.117008
# 8  -0.012581  0.067353
# 9   0.029581  0.078249
# 10  0.006151 -0.168261
# 11  0.012162  0.024041
# 12  0.021149 -0.055623

# %%
#Calcular la media
d.mean()
# Out:
# BLUE       9.080846
# ORANGE    11.944631
# dtype: float64

# %%
#desviacion estandar
d.std()
# Out:
# BLUE      0.393871
# ORANGE    1.051976
# dtype: float64

# %%
#Rendimientos compuestos
rendimientos=(1+d).cumprod()-1
rendimientos
# Out:
#             BLUE        ORANGE
# 0   8.700000e+00  1.066000e+01
# 1   9.508335e+01  1.398854e+02
# 2   9.320942e+02  1.648769e+03
# 3   8.802371e+03  2.077074e+04
# 4   8.561530e+04  2.722542e+05
# 5   8.608795e+05  3.481490e+06
# 6   8.566965e+06  4.250134e+07
# 7   8.775914e+07  5.745842e+08
# 8   8.887895e+08  8.252408e+09
# 9   9.241278e+09  1.271531e+11
# 10  9.662126e+10  1.650918e+12
# 11  1.021325e+12  2.191065e+13
# 12  1.100253e+13  2.758375e+14

# %%
#Anuallizar el rendimiento de un periodo mensualmetnte
mensual= 0.1
anualizar_m=(1+mensual)**12-1
anualizar_m
# Out:
# 2.138428376721003

# %%
#Anualizar el rendimiento de u trimestralmente
trimestralmente= 0.4
anualizar_t=(1+trimestralmente)**4-1
anualizar_t
# Out:
# 2.8415999999999992

# %%
#Anualizar el rendimiento de un periodo diario
diario=.0001
anualizar_d=(1+ diario)**252-1
anualizar_d
# Out:
# 0.025518911987694626

# %%
#Anualizar el rendimiento mensual
volatilidad_m= anualizar_m*(12**0.5)
volatilidad_m
# Out:
# 7.407733193655633

# %%
#Anualizar el rendimiento trimestral
volatilidad_t= anualizar_t*(4**0.5)
volatilidad_t
# Out:
# 5.6831999999999985

# %%
#anualizar la volatilidad diario
volatilidad_d=anualizar_d*(252**0.5)
volatilidad_d
# Out:
# 0.4051001690903097

# %%
#atributos a tu clase
def compuestos():
    r=(1+d).cumprod()-1
    return r

# %%
compuestos()
# Out:
#              AA            BB
# 0  8.887821e+00  1.014861e+01
# 1  9.326724e+01  1.158917e+02
# 2  8.626524e+02  1.590338e+03
# 3  8.961716e+03  1.744714e+04
# 4  9.001856e+04  2.389211e+05
# 5  1.199125e+06  3.742947e+06
# 6  1.473450e+07  3.603388e+07
# 7  1.463030e+08  3.826222e+08
# 8  1.199718e+09  5.786734e+09
# 9  5.990318e+09  9.243148e+10

# %%
#diccionario para data frame
Lista_1= np.random.normal(10,2,10)
Lista_1
# Out:
# array([11.45201666,  6.83637875, 11.72686246, 10.45338711, 10.31991635,
#         7.06106607,  9.04117916, 12.68697314,  6.91809524,  9.50336933])

# %%
#diccionario para data frame
Lista_2 = np.random.normal(10,2,10)
Lista_2
# Out:
# array([ 7.32012043,  9.12477553,  9.06533586,  9.55478375, 10.64585807,
#        10.19392457, 12.72205041,  8.82576643, 13.72058892,  7.9723057 ])

# %%
#Data frame
diccionario= {"Stock A": Lista_1,
             "Stock B": Lista_2}
d=pd.DataFrame(diccionario)
diccionario
d
# Out:
#      Stock A    Stock B
# 0  11.452017   7.320120
# 1   6.836379   9.124776
# 2  11.726862   9.065336
# 3  10.453387   9.554784
# 4  10.319916  10.645858
# 5   7.061066  10.193925
# 6   9.041179  12.722050
# 7  12.686973   8.825766
# 8   6.918095  13.720589
# 9   9.503369   7.972306

# %%
#Rendimiento total
rendimientos=(1+d).cumprod()-1
rendimientos
# Out:
#         Stock A       Stock B
# 0  1.145202e+01  7.320120e+00
# 1  9.657872e+01  8.323935e+01
# 2  1.240871e+03  8.468974e+02
# 3  1.422263e+04  8.948373e+03
# 4  1.610093e+05  1.042221e+05
# 5  1.297914e+06  1.166665e+06
# 6  1.303259e+07  1.600905e+07
# 7  1.783767e+08  1.573012e+08
# 8  1.412404e+09  2.315566e+09
# 9  1.483500e+10  2.077596e+10

# %%
#media
d.mean()
# Out:
# Stock A    9.599924
# Stock B    9.914551
# dtype: float64

# %%
#desviacion estandar
d.std()
# Out:
# Stock A    2.116797
# Stock B    2.003997
# dtype: float64

# %%
#anualiza la desviacion
d.std()*252**(0.5)
# Out:
# AA    35.551103
# BB    37.902396
# dtype: float64

# %% [markdown]
# #Ejercicio 8

# %%
#diccionario para data frame
Lista_1= np.random.normal(10,2,10)
Lista_1
# Out:
# array([ 8.88782124,  8.53367105,  8.16174572,  9.37768908,  9.04378126,
#        12.3207317 , 11.28769832,  8.92927925,  7.20022957,  3.99310408])

# %%
#diccionario para data frame
Lista_2 = np.random.normal(10,2,10)
Lista_2
# Out:
# array([10.14860541,  9.48487255, 12.61378127,  9.96444747, 12.6932691 ,
#        14.6659747 ,  8.62714004,  9.61839985, 14.1238847 , 14.9729964 ])

# %%
#Data frame
diccionario= {"AA": Lista_1,
             "BB": Lista_2}
d=pd.DataFrame(diccionario)
diccionario
d
# Out:
#           AA         BB
# 0   8.887821  10.148605
# 1   8.533671   9.484873
# 2   8.161746  12.613781
# 3   9.377689   9.964447
# 4   9.043781  12.693269
# 5  12.320732  14.665975
# 6  11.287698   8.627140
# 7   8.929279   9.618400
# 8   7.200230  14.123885
# 9   3.993104  14.972996

# %%
#desviacion estandar
d.std()
# Out:
# AA    2.239509
# BB    2.387626
# dtype: float64

# %%
if "AA">"BB":
  print("El activo AA es más volatil")
elif "AA"<"BB":
  print("El activo BB es más volatil")
else:
  print("Ambos activos tienen la misma volatilidad")
# Out:
# El activo BB es más volatil

# %% [markdown]
# #Ejercicio 9

# %%
##Cargar dos tickers
import yfinance as yf
start= "2011-01-01"
end= "2019-01-01"
amazon=yf.download("AMZN",start,end)
ko=yf.download("KO",start,end)
msft=yf.download("MSFT",start,end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
amazon
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2011-01-03   9.068500   9.300000   9.060500   9.211000   9.211000  106628000
# 2011-01-04   9.307500   9.385000   9.189000   9.250500   9.250500  100636000
# 2011-01-05   9.205000   9.372500   9.203500   9.371000   9.371000   68376000
# 2011-01-06   9.325000   9.370500   9.262500   9.293000   9.293000   63594000
# 2011-01-07   9.394000   9.422500   9.187000   9.274500   9.274500  104434000
# ...               ...        ...        ...        ...        ...        ...
# 2018-12-24  67.300003  69.801498  65.349998  67.197998  67.197998  144400000
# 2018-12-26  68.444504  73.657997  68.150497  73.544998  73.544998  208236000
# 2018-12-27  72.709999  73.449997  69.515503  73.082001  73.082001  194440000
# 2018-12-28  73.667503  75.673500  72.449997  73.901001  73.901001  176580000
# 2018-12-31  75.540001  76.038002  74.349998  75.098503  75.098503  139090000
#
# [2012 rows x 6 columns]

# %%
amazon.mean()
# Out:
# Open         3.021916e+01
# High         3.052008e+01
# Low          2.986222e+01
# Close        3.020373e+01
# Adj Close    3.020373e+01
# Volume       8.532124e+07
# dtype: float64

# %%
amazon.std()
# Out:
# Open         2.367613e+01
# High         2.390543e+01
# Low          2.336091e+01
# Close        2.363465e+01
# Adj Close    2.363465e+01
# Volume       4.977279e+07
# dtype: float64

# %%
amazon.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2012.000000  2012.000000  2012.000000  2012.000000  2012.000000
# mean     30.219156    30.520085    29.862218    30.203726    30.203726
# std      23.676134    23.905433    23.360914    23.634649    23.634649
# min       8.059500     8.177000     8.029500     8.048500     8.048500
# 25%      12.879750    12.989500    12.750375    12.892750    12.892750
# 50%      18.772249    18.957750    18.650000    18.757000    18.757000
# 75%      40.930001    41.086875    40.650000    40.900001    40.900001
# max     101.905502   102.525002   100.650002   101.975502   101.975502
#
#              Volume
# count  2.012000e+03
# mean   8.532124e+07
# std    4.977279e+07
# min    1.968800e+07
# 25%    5.405600e+07
# 50%    7.274700e+07
# 75%    9.910400e+07
# max    4.826840e+08

# %%
rendimientos=amazon.pct_change().dropna()
rendimientos
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2011-01-04  0.026355  0.009140  0.014182  0.004288   0.004288 -0.056195
# 2011-01-05 -0.011013 -0.001332  0.001578  0.013026   0.013026 -0.320561
# 2011-01-06  0.013036 -0.000213  0.006411 -0.008324  -0.008324 -0.069937
# 2011-01-07  0.007399  0.005549 -0.008151 -0.001991  -0.001991  0.642199
# 2011-01-10 -0.015116 -0.016768 -0.006694 -0.004367  -0.004367 -0.353486
# ...              ...       ...       ...       ...        ...       ...
# 2018-12-24 -0.081222 -0.056737 -0.041761 -0.024313  -0.024313 -0.470686
# 2018-12-26  0.017006  0.055250  0.042854  0.094452   0.094452  0.442078
# 2018-12-27  0.062320 -0.002824  0.020029 -0.006295  -0.006295 -0.066252
# 2018-12-28  0.013169  0.030272  0.042214  0.011207   0.011207 -0.091854
# 2018-12-31  0.025418  0.004817  0.026225  0.016204   0.016204 -0.212312
#
# [2011 rows x 6 columns]

# %%
amazon.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Adj Close'}>,
#         <Axes: title={'center': 'Volume'}>]], dtype=object)

# %%
ko
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2011-01-03  32.939999  32.939999  32.555000  32.610001  21.990664  18945600
# 2011-01-04  32.509998  32.595001  31.905001  31.934999  21.535463  27940400
# 2011-01-05  31.895000  31.975000  31.430000  31.745001  21.407337  34379000
# 2011-01-06  31.809999  31.830000  31.415001  31.514999  21.252234  21712400
# 2011-01-07  31.389999  31.500000  31.280001  31.459999  21.215145  16592800
# ...               ...        ...        ...        ...        ...       ...
# 2018-12-24  47.619999  47.869999  45.830002  45.959999  39.630630  10733700
# 2018-12-26  45.880001  46.959999  45.660000  46.939999  40.475666  14342600
# 2018-12-27  46.740002  47.549999  46.029999  47.529999  40.984417  16966500
# 2018-12-28  47.889999  48.009998  47.029999  47.200001  40.699863  13218200
# 2018-12-31  47.490002  47.540001  46.959999  47.349998  40.829205  10576300
#
# [2012 rows x 6 columns]

# %%
ko.mean()
# Out:
# Open         4.066799e+01
# High         4.091321e+01
# Low          4.042888e+01
# Close        4.067860e+01
# Adj Close    3.108642e+01
# Volume       1.435038e+07
# dtype: float64

# %%
ko.std()
# Out:
# Open         4.088640e+00
# High         4.110775e+00
# Low          4.080065e+00
# Close        4.098414e+00
# Adj Close    5.129423e+00
# Volume       6.066524e+06
# dtype: float64

# %%
ko.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2012.000000  2012.000000  2012.000000  2012.000000  2012.000000
# mean     40.667995    40.913206    40.428877    40.678596    31.086421
# std       4.088640     4.110775     4.080065     4.098414     5.129423
# min      31.160000    31.334999    30.645000    30.799999    20.920673
# 25%      38.160000    38.445001    37.919998    38.150002    27.220245
# 50%      41.130001    41.380001    40.880001    41.169998    31.144288
# 75%      43.572500    43.830002    43.369999    43.602499    35.135604
# max      50.820000    50.840000    50.250000    50.509998    43.459183
#
#              Volume
# count  2.012000e+03
# mean   1.435038e+07
# std    6.066524e+06
# min    2.996300e+06
# 25%    1.054238e+07
# 50%    1.307745e+07
# 75%    1.650562e+07
# max    9.896750e+07

# %%
rendimientos=ko.pct_change().dropna()
rendimientos
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2011-01-04 -0.013054 -0.010474 -0.019966 -0.020699  -0.020700  0.474770
# 2011-01-05 -0.018917 -0.019021 -0.014888 -0.005950  -0.005950  0.230441
# 2011-01-06 -0.002665 -0.004535 -0.000477 -0.007245  -0.007245 -0.368440
# 2011-01-07 -0.013203 -0.010368 -0.004297 -0.001745  -0.001745 -0.235792
# 2011-01-10 -0.001274  0.003175  0.000000  0.002225   0.002225 -0.101743
# ...              ...       ...       ...       ...        ...       ...
# 2018-12-24  0.007617 -0.018051 -0.029642 -0.033845  -0.033845 -0.669506
# 2018-12-26 -0.036539 -0.019010 -0.003709  0.021323   0.021323  0.336221
# 2018-12-27  0.018745  0.012564  0.008103  0.012569   0.012569  0.182945
# 2018-12-28  0.024604  0.009674  0.021725 -0.006943  -0.006943 -0.220924
# 2018-12-31 -0.008352 -0.009790 -0.001488  0.003178   0.003178 -0.199868
#
# [2011 rows x 6 columns]

# %%
ko.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Adj Close'}>,
#         <Axes: title={'center': 'Volume'}>]], dtype=object)

# %%
msft
# Out:
#                   Open        High         Low       Close  Adj Close  \
# Date
# 2011-01-03   28.049999   28.180000   27.920000   27.980000  21.708212
# 2011-01-04   27.940001   28.170000   27.850000   28.090000  21.793550
# 2011-01-05   27.900000   28.010000   27.770000   28.000000  21.723730
# 2011-01-06   28.040001   28.850000   27.860001   28.820000  22.359922
# 2011-01-07   28.639999   28.740000   28.250000   28.600000  22.189228
# ...                ...         ...         ...         ...        ...
# 2018-12-24   97.680000   97.970001   93.980003   94.129997  89.567017
# 2018-12-26   95.139999  100.690002   93.959999  100.559998  95.685295
# 2018-12-27   99.300003  101.190002   96.400002  101.180000  96.275238
# 2018-12-28  102.089996  102.410004   99.519997  100.389999  95.523560
# 2018-12-31  101.290001  102.400002  100.440002  101.570000  96.646339
#
#               Volume
# Date
# 2011-01-03  53443800
# 2011-01-04  54405600
# 2011-01-05  58998700
# 2011-01-06  88026300
# ...

# %%
msft.mean()
# Out:
# Open         5.070010e+01
# High         5.113093e+01
# Low          5.024623e+01
# Close        5.071150e+01
# Adj Close    4.510661e+01
# Volume       3.894994e+07
# dtype: float64

# %%
msft.std()
# Out:
# Open         2.410360e+01
# High         2.431149e+01
# Low          2.383243e+01
# Close        2.407645e+01
# Adj Close    2.409227e+01
# Volume       2.189613e+07
# dtype: float64

# %%
msft.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2012.000000  2012.000000  2012.000000  2012.000000  2012.000000
# mean     50.700099    51.130934    50.246233    50.711501    45.106610
# std      24.103602    24.311489    23.832428    24.076450    24.092269
# min      23.750000    24.010000    23.650000    23.709999    18.625359
# 25%      30.690001    30.959999    30.437500    30.740000    24.854783
# 50%      44.545000    44.980000    44.090000    44.400002    38.812201
# 75%      62.700001    63.090001    62.284999    62.650000    57.318742
# max     115.419998   116.180000   114.930000   115.610001   109.532547
#
#              Volume
# count  2.012000e+03
# mean   3.894994e+07
# std    2.189613e+07
# min    7.425600e+06
# 25%    2.460210e+07
# 50%    3.395135e+07
# 75%    4.792632e+07
# max    3.193179e+08

# %%
rendimientos=msft.pct_change().dropna()
rendimientos
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2011-01-04 -0.003922 -0.000355 -0.002507  0.003931   0.003931  0.017996
# 2011-01-05 -0.001432 -0.005680 -0.002873 -0.003204  -0.003204  0.084423
# 2011-01-06  0.005018  0.029989  0.003241  0.029286   0.029286  0.492004
# 2011-01-07  0.021398 -0.003813  0.013999 -0.007634  -0.007634 -0.162046
# 2011-01-10 -0.013268 -0.011830 -0.007434 -0.013287  -0.013286 -0.219468
# ...              ...       ...       ...       ...        ...       ...
# 2018-12-24 -0.038866 -0.048835 -0.035707 -0.041739  -0.041739 -0.605049
# 2018-12-26 -0.026003  0.027764 -0.000213  0.068310   0.068310  0.175249
# 2018-12-27  0.043725  0.004966  0.025969  0.006166   0.006165 -0.041373
# 2018-12-28  0.028097  0.012057  0.032365 -0.007808  -0.007808 -0.228334
# 2018-12-31 -0.007836 -0.000098  0.009244  0.011754   0.011754 -0.131492
#
# [2011 rows x 6 columns]

# %%
msft.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Adj Close'}>,
#         <Axes: title={'center': 'Volume'}>]], dtype=object)

# %%
##Observamos que los histogramas nos muestran la informacion de cada una de las colimnas, donde va decreciendo

# %%
amazon.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ko.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
msft.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import yfinance as yf

# %%
df = yf.download(["AMZN","KO", "MSFT"], "2011-01-01", "2019-01-01")["Adj Close"]
df
# Out:
# [*********************100%%**********************]  3 of 3 completed
#                  AMZN         KO       MSFT
# Date
# 2011-01-03   9.211000  21.990656  21.708206
# 2011-01-04   9.250500  21.535467  21.793549
# 2011-01-05   9.371000  21.407341  21.723726
# 2011-01-06   9.293000  21.252237  22.359921
# 2011-01-07   9.274500  21.215149  22.189238
# ...               ...        ...        ...
# 2018-12-24  67.197998  39.630630  89.567009
# 2018-12-26  73.544998  40.475670  95.685287
# 2018-12-27  73.082001  40.984421  96.275261
# 2018-12-28  73.901001  40.699860  95.523537
# 2018-12-31  75.098503  40.829205  96.646347
#
# [2012 rows x 3 columns]
